# %%
import pandas as pd
import numpy as np
import requests
from io import StringIO

# %%
url="https://raw.githubusercontent.com/dineshpiyasamara/LaptopPricePredictor/master/model%20building/laptop_price.csv"
response=requests.get(url)

# %%
if response.status_code==200:
    data = pd.read_csv(StringIO(response.text))
else:
    print("failed to grab from github")

# %%
data.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94
# ...

# %%
data["Ram"]=data["Ram"].str.replace("GB","").astype('int32')

# %%
data.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   int32
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price_euros       1303 non-null   float64
# dtypes: float64(2), int32(1), int64(1), object(8)
# memory usage: 117.2+ KB

# %%
data['Weight']=data['Weight'].str.replace('kg','').astype('float')

# %%
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   int32
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float64
#  11  Price_euros       1303 non-null   float64
# dtypes: float64(3), int32(1), int64(1), object(7)
# memory usage: 117.2+ KB
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# ...

# %%
data.drop('laptop_ID',axis=1)
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
def func(inpt):
    if inpt == 'Samsung' or inpt == 'Razer' or inpt == 'Mediacom' or inpt == 'Microsoft'or inpt == 'Xiaomi'or inpt == 'Vero'or inpt == 'Chuwi'or inpt =='Google'or inpt == 'Fujitsu' or inpt == 'LG'or inpt == 'Huawei':
        return 'other'
    else:
        return inpt
    
data['Company']=data['Company'].apply(func)

# %%
data['Product'].value_counts()
# Out:
# Product
# XPS 13                                     30
# Inspiron 3567                              29
# 250 G6                                     21
# Legion Y520-15IKBN                         19
# Vostro 3568                                19
#                                            ..
# 15-bw007nv (A10-9620P/6GB/128GB/Radeon      1
# SmartBook 130                               1
# A541NA-GO342 (N3350/4GB/500GB/Linux)        1
# 17-X047na (i3-6006U/8GB/1TB/W10)            1
# V330-15IKB (i5-8250U/4GB/500GB/FHD/W10)     1
# Name: count, Length: 618, dtype: int64

# %%
data.drop('Product',axis=1)
# Out:
#       laptop_ID Company            TypeName  Inches  \
# 0             1   Apple           Ultrabook    13.3
# 1             2   Apple           Ultrabook    13.3
# 2             3      HP            Notebook    15.6
# 3             4   Apple           Ultrabook    15.4
# 4             5   Apple           Ultrabook    13.3
# ...         ...     ...                 ...     ...
# 1298       1316  Lenovo  2 in 1 Convertible    14.0
# 1299       1317  Lenovo  2 in 1 Convertible    13.3
# 1300       1318  Lenovo            Notebook    14.0
# 1301       1319      HP            Notebook    15.6
# 1302       1320    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
data['ScreenResolution'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0               IPS Panel Retina Display 2560x1600
# 1                                         1440x900
# 2                                Full HD 1920x1080
# 3               IPS Panel Retina Display 2880x1800
# 4               IPS Panel Retina Display 2560x1600
#                            ...
# 1298     IPS Panel Full HD / Touchscreen 1920x1080
# 1299    IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                      1366x768
# 1301                                      1366x768
# 1302                                      1366x768
# Name: ScreenResolution, Length: 1303, dtype: object>

# %%
data['Touchscreen'] =data['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
data['IPS panel']   =data['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
data['Full HD']     =data['ScreenResolution'].apply(lambda x:1 if 'Full' in x else 0)

# %%
data.drop('ScreenResolution',axis=1)
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                                   Cpu  Ram  \
# 0              Ultrabook    13.3                  Intel Core i5 2.3GHz    8
# 1              Ultrabook    13.3                  Intel Core i5 1.8GHz    8
# ...

# %%
data['cpu_name']=data['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
data.drop('Cpu',axis=1)
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
data['cpu_name'].value_counts()
# Out:
# cpu_name
# Intel Core i7               527
# Intel Core i5               423
# Intel Core i3               136
# Intel Celeron Dual           80
# Intel Pentium Quad           27
# Intel Core M                 19
# AMD A9-Series 9420           12
# Intel Celeron Quad            8
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# AMD A8-Series 7410            4
# Intel Atom x5-Z8550           4
# Intel Pentium Dual            3
# AMD A9-Series 9410            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9620P          2
# Intel Atom X5-Z8350           2
# AMD E-Series E2-9000e         2
# Intel Xeon E3-1535M           2
# Intel Xeon E3-1505M           2
# AMD E-Series 7110             2
# AMD A10-Series 9600P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# AMD Ryzen 1600                1
# Intel Atom x5-Z8300           1
# AMD E-Series E2-6110          1
# ...

# %%
def set_processor(name):
    if name=='Intel Core i7' or name=='Intel Core i5' or name=='Intel Core i3' or name=='Intel Celeron Dual' or name=='Intel Pentium Quad' or name=='Intel Core M':
        return name
    else:
        if name.split()[0]=='AMD':
            return 'AMD'
        
        else:
            return 'other'
        
data['cpu_name']=data['cpu_name'].apply(set_processor)

# %%
data['cpu_name'].value_counts()
# Out:
# cpu_name
# Intel Core i7         527
# Intel Core i5         423
# Intel Core i3         136
# Intel Celeron Dual     80
# AMD                    62
# other                  29
# Intel Pentium Quad     27
# Intel Core M           19
# Name: count, dtype: int64

# %%
data.head(10)
# Out:
#    laptop_ID Company          Product   TypeName  Inches  \
# 0          1   Apple      MacBook Pro  Ultrabook    13.3
# 1          2   Apple      Macbook Air  Ultrabook    13.3
# 2          3      HP           250 G6   Notebook    15.6
# 3          4   Apple      MacBook Pro  Ultrabook    15.4
# 4          5   Apple      MacBook Pro  Ultrabook    13.3
# 5          6    Acer         Aspire 3   Notebook    15.6
# 6          7   Apple      MacBook Pro  Ultrabook    15.4
# 7          8   Apple      Macbook Air  Ultrabook    13.3
# 8          9    Asus  ZenBook UX430UN  Ultrabook    14.0
# 9         10    Acer          Swift 3  Ultrabook    14.0
#
#                      ScreenResolution                         Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# ...

# %%
data['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
def func(name):
    y=name.split()[0:1]
    x="".join(y)
    return x
data['Gpu name']=data['Gpu'].apply(func)

# %%
data['Gpu name'].value_counts()
# Out:
# Gpu name
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (1303, 17)

# %%
z=data['Gpu name']
data= data[ z !='ARM']

# %%
data['Gpu name'].value_counts()
# Out:
# Gpu name
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
data.head(2)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
#
#                      ScreenResolution                   Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz    8
# 1                            1440x900  Intel Core i5 1.8GHz    8
#
#                             Gpu  OpSys  Weight  Price_euros  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69            0
# 1        Intel HD Graphics 6000  macOS    1.34       898.94            0
#
#    IPS panel  Full HD       cpu_name Gpu name
# 0          1        0  Intel Core i5    Intel
# 1          0        0  Intel Core i5    Intel

# %%
data.drop("Gpu",axis=1)
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
data['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def func(x):
    if x=='Windows 10' or x=="Windows 7":
        return 'Windows'
    elif (x=="macOS" or x=='Mac OS X'):
        return 'Mac'
    elif x=="Linux":
        return x
    else:
        return 'other'

data['OpSys'] = data['OpSys'].apply(func)

# %%
data['OpSys'].value_counts()
# Out:
# OpSys
# Windows    1117
# other       102
# Linux        62
# Mac          21
# Name: count, dtype: int64

# %%
data.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#                             Gpu  OpSys  Weight  Price_euros  Touchscreen  \
# 0  Intel Iris Plus Graphics 640    Mac    1.37      1339.69            0
# ...

# %%
data= data.drop(['laptop_ID','Inches','Product','Cpu','Gpu'], axis=1)

# %%
data=data.drop('ScreenResolution',axis=1)

# %%
data.head(4)
# Out:
#   Company   TypeName  Ram  OpSys  Weight  Price_euros  Touchscreen  IPS panel  \
# 0   Apple  Ultrabook    8    Mac    1.37      1339.69            0          1
# 1   Apple  Ultrabook    8    Mac    1.34       898.94            0          0
# 2      HP   Notebook    8  other    1.86       575.00            0          0
# 3   Apple  Ultrabook   16    Mac    1.83      2537.45            0          1
#
#    Full HD       cpu_name Gpu name
# 0        0  Intel Core i5    Intel
# 1        0  Intel Core i5    Intel
# 2        1  Intel Core i5    Intel
# 3        0  Intel Core i7      AMD

# %%
#using one hot encoding
#new columns will be created for 'company','typename','cpu_name','Gpu name'
data=pd.get_dummies(data)

# %%
data.head(2)
# Out:
#    Ram  Weight  Price_euros  Touchscreen  IPS panel  Full HD  Company_Acer  \
# 0    8    1.37      1339.69            0          1        0         False
# 1    8    1.34       898.94            0          0        0         False
#
#    Company_Apple  Company_Asus  Company_Dell  ...  \
# 0           True         False         False  ...
# 1           True         False         False  ...
#
#    cpu_name_Intel Celeron Dual  cpu_name_Intel Core M  cpu_name_Intel Core i3  \
# 0                        False                  False                   False
# 1                        False                  False                   False
#
#    cpu_name_Intel Core i5  cpu_name_Intel Core i7  \
# 0                    True                   False
# 1                    True                   False
#
#    cpu_name_Intel Pentium Quad  cpu_name_other  Gpu name_AMD  Gpu name_Intel  \
# 0                        False           False         False            True
# ...

# %%
data.shape
# Out:
# (1302, 36)

# %%
X= data.drop('Price_euros',axis=1)
y=data['Price_euros']

# %%
X.head()
# Out:
#    Ram  Weight  Touchscreen  IPS panel  Full HD  Company_Acer  Company_Apple  \
# 0    8    1.37            0          1        0         False           True
# 1    8    1.34            0          0        0         False           True
# 2    8    1.86            0          0        1         False          False
# 3   16    1.83            0          1        0         False           True
# 4    8    1.37            0          1        0         False           True
#
#    Company_Asus  Company_Dell  Company_HP  ...  cpu_name_Intel Celeron Dual  \
# 0         False         False       False  ...                        False
# 1         False         False       False  ...                        False
# 2         False         False        True  ...                        False
# 3         False         False       False  ...                        False
# 4         False         False       False  ...                        False
#
# ...

# %%
y.head()
# Out:
# 0    1339.69
# 1     898.94
# 2     575.00
# 3    2537.45
# 4    1803.60
# Name: Price_euros, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test= train_test_split(X.values,y.values, test_size=0.25)

# %%
X_train.shape, X_test.shape
# Out:
# ((976, 35), (326, 35))

# %%
X_test
# Out:
# array([[4, 1.76, 0, ..., False, True, False],
#        [16, 2.5, 0, ..., True, False, False],
#        [4, 1.25, 1, ..., False, True, False],
#        ...,
#        [8, 2.3, 1, ..., False, True, False],
#        [8, 2.4, 0, ..., False, False, True],
#        [16, 4.0, 0, ..., False, False, True]], dtype=object)

# %%
#to train on different models
def model_accuracy(model):
    model.fit(X_train, y_train)
    accuracy= model.score(X_test, y_test)
    print('accuracy of'+str(model)+"is: "+str(accuracy))

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
model_accuracy(lr)
# Out:
# accuracy ofLinearRegression()is: 0.724306723823664

# %%
from sklearn.linear_model import Lasso
lasso=Lasso()
model_accuracy(lasso)
# Out:
# accuracy ofLasso()is: 0.7250727207532143

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
model_accuracy(dt)
# Out:
# accuracy ofDecisionTreeRegressor()is: 0.6420729307713127

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
model_accuracy(rf)
# Out:
# accuracy ofRandomForestRegressor()is: 0.8150858215492196

# %%
#using grid search cv to find the best hyper parameter
from sklearn.model_selection import GridSearchCV
parameters={'n_estimators':[1,5,10,50,100],'criterion':['squared_error','absolute_error','poisson']}
gridObj= GridSearchCV(estimator=rf, param_grid=parameters)
gridFit= gridObj.fit(X_train, y_train)
bestModel=gridFit.best_estimator_
bestModel
# Out:
# RandomForestRegressor(n_estimators=50)

# %%
bestModel.score(X_test, y_test)
# Out:
# 0.8241367914749407

# %%
model_accuracy(rf)
# Out:
# accuracy ofRandomForestRegressor()is: 0.8223570887222562

# %%
bestModel= rf

# %%
bestModel
# Out:
# RandomForestRegressor()

# %%
#we can import pickle and serialize our model
import pickle

# %%
with open('predictor.pickle','wb') as file:
    pickle.dump(bestModel, file ) #dumping the best model to a file

# %%
data.rename(columns={'Price_euros':'Price LKR'},inplace=True)

# %%
data['Price LKR']=data['Price LKR'].apply(lambda x:x*350.21)

# %%
column_to_move='Price LKR'
data.insert(0, column_to_move, data.pop(column_to_move))

# %%
filepath='output.csv'
data.to_csv(filepath,index=False)

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ------------
# anyio                     4.0.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.2.3
# asttokens                 2.4.0
# async-lru                 2.0.4
# attrs                     23.1.0
# Babel                     2.12.1
# backcall                  0.2.0
# beautifulsoup4            4.12.2
# bleach                    6.0.0
# blinker                   1.6.2
# certifi                   2023.7.22
# cffi                      1.15.1
# charset-normalizer        3.2.0
# click                     8.1.7
# colorama                  0.4.6
# comm                      0.1.4
# contourpy                 1.1.0
# cycler                    0.11.0
# debugpy                   1.8.0
# decorator                 5.1.1
# defusedxml                0.7.1
# executing                 1.2.0
# fastjsonschema            2.18.0
# Flask                     2.3.3
# ...
